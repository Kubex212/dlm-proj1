# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.python.client import device_lib
import random
import keras
from keras import regularizers

# %%
historyCNN = pd.read_csv('CNN_na_czysto.csv')
historyResNet = pd.read_csv('ResNet18.csv')
historyCNN.describe()
# Out:
#        Unnamed: 0        loss    accuracy    val_loss  val_accuracy
# count  100.000000  100.000000  100.000000  100.000000    100.000000
# mean    49.500000    0.196796    0.934390    4.315342      0.592236
# std     29.011492    0.259298    0.096185    1.718327      0.014187
# min      0.000000    0.083724    0.427500    1.076397      0.485222
# 25%     24.750000    0.092318    0.954103    3.094366      0.588261
# 50%     49.500000    0.100605    0.970117    4.613714      0.591161
# 75%     74.250000    0.136572    0.974847    5.742353      0.596158
# max     99.000000    1.549579    0.979456    6.945212      0.622622

# %%
plt.plot(historyCNN['Unnamed: 0'].head(40), historyCNN['val_accuracy'].head(40), label = "CNN")
plt.plot(historyResNet['Unnamed: 0'], historyResNet['val_accuracy'], label = "ResNet18")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('CNN and ResNet18 architecture comparison')
plt.legend()

# %%
plt.plot(historyCNN['Unnamed: 0'].head(40), historyCNN['accuracy'].head(40), label = "CNN")
plt.plot(historyResNet['Unnamed: 0'], historyResNet['accuracy'], label = "ResNet18")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('CNN and ResNet18 architecture comparison')
plt.legend()

# %%
historyCNN_8 = pd.read_csv('CNN_na_czysto_batch_8.csv')
historyCNN_16 = pd.read_csv('CNN_na_czysto_batch_16.csv')
historyCNN_32 = pd.read_csv('CNN_na_czysto_batch_32.csv')
historyCNN_64 = pd.read_csv('CNN_na_czysto.csv')
historyCNN_128 = pd.read_csv('CNN_na_czysto_batch_128.csv')


plt.plot(historyCNN_8['Unnamed: 0'], historyCNN_8['accuracy'], label = "CNN Batch Size 8")
plt.plot(historyCNN_16['Unnamed: 0'], historyCNN_16['accuracy'], label = "CNN Batch Size 16")
plt.plot(historyCNN_32['Unnamed: 0'], historyCNN_32['accuracy'], label = "CNN Batch Size 32")
plt.plot(historyCNN_64['Unnamed: 0'], historyCNN_64['accuracy'], label = "CNN Batch Size 64")
plt.plot(historyCNN_128['Unnamed: 0'], historyCNN_128['accuracy'], label = "CNN Batch Size 128")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('CNN batch size influence (Training set)')
plt.legend()

# %%
plt.plot(historyCNN_8['Unnamed: 0'], historyCNN_8['val_accuracy'], label = "CNN Batch Size 8")
plt.plot(historyCNN_16['Unnamed: 0'], historyCNN_16['val_accuracy'], label = "CNN Batch Size 16")
plt.plot(historyCNN_32['Unnamed: 0'], historyCNN_32['val_accuracy'], label = "CNN Batch Size 32")
plt.plot(historyCNN_64['Unnamed: 0'], historyCNN_64['val_accuracy'], label = "CNN Batch Size 64")
plt.plot(historyCNN_128['Unnamed: 0'], historyCNN_128['val_accuracy'], label = "CNN Batch Size 128")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('CNN batch size influence (Test set)')
plt.legend()

# %%
historyCNN_16 = pd.read_csv('ResNet18_batch_16.csv')
historyCNN_32 = pd.read_csv('ResNet18_batch_32.csv')
historyCNN_64 = pd.read_csv('ResNet18.csv')

plt.plot(historyCNN_16['Unnamed: 0'], historyCNN_16['accuracy'], label = "ResNet18 Batch Size 16")
plt.plot(historyCNN_32['Unnamed: 0'], historyCNN_32['accuracy'], label = "ResNet18 Batch Size 32")
plt.plot(historyCNN_64['Unnamed: 0'], historyCNN_64['accuracy'], label = "ResNet18 Batch Size 64")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('ResNet18 batch size influence (Training set)')
plt.legend()

# %%
plt.plot(historyCNN_16['Unnamed: 0'], historyCNN_16['val_accuracy'], label = "ResNet18 Batch Size 16")
plt.plot(historyCNN_32['Unnamed: 0'], historyCNN_32['val_accuracy'], label = "ResNet18 Batch Size 32")
plt.plot(historyCNN_64['Unnamed: 0'], historyCNN_64['val_accuracy'], label = "ResNet18 Batch Size 64")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('ResNet18 batch size influence (Test set)')
plt.legend()

# %%
historyCNN = pd.read_csv('CNN_na_czysto.csv')
historyCNN_dropout_0_1 = pd.read_csv('CNN_dropout_0_1.csv')
historyCNN_dropout_0_3 = pd.read_csv('CNN_dropout_0_3.csv')
historyCNN_dropout_0_5 = pd.read_csv('CNN_dropout_0_5.csv')

plt.plot(historyCNN['Unnamed: 0'], historyCNN['val_accuracy'], label = "CNN")
plt.plot(historyCNN_dropout_0_1['Unnamed: 0'], historyCNN_dropout_0_1['val_accuracy'], label = "CNN dropout 0.1")
plt.plot(historyCNN_dropout_0_3['Unnamed: 0'], historyCNN_dropout_0_3['val_accuracy'], label = "CNN dropout 0.3")
plt.plot(historyCNN_dropout_0_5['Unnamed: 0'], historyCNN_dropout_0_5['val_accuracy'], label = "CNN dropout 0.5")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('CNN dropout influence (Test set)')
plt.legend()

# %%
plt.plot(historyCNN['Unnamed: 0'], historyCNN['accuracy'], label = "CNN")
plt.plot(historyCNN_dropout_0_1['Unnamed: 0'], historyCNN_dropout_0_1['accuracy'], label = "CNN dropout 0.1")
plt.plot(historyCNN_dropout_0_3['Unnamed: 0'], historyCNN_dropout_0_3['accuracy'], label = "CNN dropout 0.3")
plt.plot(historyCNN_dropout_0_5['Unnamed: 0'], historyCNN_dropout_0_5['accuracy'], label = "CNN dropout 0.5")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('CNN dropout influence (Training set)')
plt.legend()

# %%
historyCNN = pd.read_csv('CNN_na_czysto.csv')
historyCNN_regulatization_0_1 = pd.read_csv('CNN_regulatization_0.1.csv')
historyCNN_regulatization_0_2 = pd.read_csv('CNN_regulatization_0.2.csv')
historyCNN_regulatization_0_3 = pd.read_csv('CNN_regulatization_0.3.csv')

plt.plot(historyCNN['Unnamed: 0'], historyCNN['val_accuracy'], label = "CNN")
plt.plot(historyCNN_regulatization_0_1['Unnamed: 0'], historyCNN_regulatization_0_1['val_accuracy'], label = "CNN L2 regularization λ = 0.1")
plt.plot(historyCNN_regulatization_0_2['Unnamed: 0'], historyCNN_regulatization_0_2['val_accuracy'], label = "CNN L2 regularization λ = 0.3")
plt.plot(historyCNN_regulatization_0_3['Unnamed: 0'], historyCNN_regulatization_0_3['val_accuracy'], label = "CNN L2 regularization λ = 0.5")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('CNN regularization L2, λ influence (Test set)')
plt.legend()

# %%
plt.plot(historyCNN['Unnamed: 0'], historyCNN['accuracy'], label = "CNN")
plt.plot(historyCNN_regulatization_0_1['Unnamed: 0'], historyCNN_regulatization_0_1['accuracy'], label = "CNN L2 regularization λ = 0.1")
plt.plot(historyCNN_regulatization_0_2['Unnamed: 0'], historyCNN_regulatization_0_2['accuracy'], label = "CNN L2 regularization λ = 0.3")
plt.plot(historyCNN_regulatization_0_3['Unnamed: 0'], historyCNN_regulatization_0_3['accuracy'], label = "CNN L2 regularization λ = 0.5")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('CNN regularization L2, λ influence (Training set)')
plt.legend()

# %%
historyCNN = pd.read_csv('CNN_na_czysto.csv')
historyCNN_regulatization_0_1 = pd.read_csv('CNN_regulatization_L1_0_1.csv')
historyCNN_regulatization_0_2 = pd.read_csv('CNN_regulatization_L1_0_2.csv')
historyCNN_regulatization_0_3 = pd.read_csv('CNN_regulatization_L1_0_3.csv')

plt.plot(historyCNN['Unnamed: 0'], historyCNN['val_accuracy'], label = "CNN")
plt.plot(historyCNN_regulatization_0_1['Unnamed: 0'], historyCNN_regulatization_0_1['val_accuracy'], label = "CNN L1 regularization λ = 0.1")
plt.plot(historyCNN_regulatization_0_2['Unnamed: 0'], historyCNN_regulatization_0_2['val_accuracy'], label = "CNN L1 regularization λ = 0.3")
plt.plot(historyCNN_regulatization_0_3['Unnamed: 0'], historyCNN_regulatization_0_3['val_accuracy'], label = "CNN L1 regularization λ = 0.5")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('CNN regularization L1, λ influence (Test set)')
plt.legend()

# %%
plt.plot(historyCNN['Unnamed: 0'], historyCNN['accuracy'], label = "CNN")
plt.plot(historyCNN_regulatization_0_1['Unnamed: 0'], historyCNN_regulatization_0_1['accuracy'], label = "CNN L1 regularization λ = 0.1")
plt.plot(historyCNN_regulatization_0_2['Unnamed: 0'], historyCNN_regulatization_0_2['accuracy'], label = "CNN L1 regularization λ = 0.3")
plt.plot(historyCNN_regulatization_0_3['Unnamed: 0'], historyCNN_regulatization_0_3['accuracy'], label = "CNN L1 regularization λ = 0.5")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('CNN regularization L1, λ influence (Training set)')
plt.legend()

# %%
datagen=ImageDataGenerator(
    width_shift_range=0.3,
    height_shift_range=0.3,
    fill_mode='nearest'
)
imagegen=datagen.flow_from_directory('data/show',batch_size=1)

for i in range(4):
    plt.imshow(imagegen.next()[0][0].astype('uint8'))
    plt.show()
# Out:
# Found 1 images belonging to 1 classes.

# %%
datagen=ImageDataGenerator(
    rotation_range=45,
    fill_mode='nearest'
)
imagegen=datagen.flow_from_directory('data/show',batch_size=1)

for i in range(4):
    plt.imshow(imagegen.next()[0][0].astype('uint8'))
    plt.show()
# Out:
# Found 1 images belonging to 1 classes.

# %%
datagen=ImageDataGenerator(
    shear_range=45,
    fill_mode='nearest'
)
imagegen=datagen.flow_from_directory('data/show',batch_size=1)

for i in range(4):
    plt.imshow(imagegen.next()[0][0].astype('uint8'))
    plt.show()
# Out:
# Found 1 images belonging to 1 classes.

# %%
datagen=ImageDataGenerator(
    zoom_range=0.5,
    fill_mode='nearest'
)
imagegen=datagen.flow_from_directory('data/show',batch_size=1)

for i in range(4):
    plt.imshow(imagegen.next()[0][0].astype('uint8'))
    plt.show()
# Out:
# Found 1 images belonging to 1 classes.

# %%
datagen=ImageDataGenerator(
    channel_shift_range=80,
    fill_mode='nearest'
)
imagegen=datagen.flow_from_directory('data/show',batch_size=1)

for i in range(4):
    plt.imshow(imagegen.next()[0][0].astype('uint8'))
    plt.show()
# Out:
# Found 1 images belonging to 1 classes.

# %%
historyResNet18 = pd.read_csv('ResNet18_v2.csv')
historyResNet18_zoom = pd.read_csv('ResNet18_augmentation_zoom.csv')

plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['accuracy'], label = "ResNet18")
plt.plot(historyResNet18_zoom['Unnamed: 0'], historyResNet18_zoom['accuracy'], label = "ResNet18 + zoom")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('ResNet18 zoom influence (Training set)')
plt.legend()

# %%
plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['val_accuracy'], label = "ResNet18")
plt.plot(historyResNet18_zoom['Unnamed: 0'], historyResNet18_zoom['val_accuracy'], label = "ResNet18 + zoom")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('ResNet18 zoom influence (Test set)')
plt.legend()

# %%
historyResNet18 = pd.read_csv('ResNet18_v2.csv')
historyResNet18_shear = pd.read_csv('ResNet18_augmentation_shear.csv')

plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['accuracy'], label = "ResNet18")
plt.plot(historyResNet18_shear['Unnamed: 0'], historyResNet18_shear['accuracy'], label = "ResNet18 + shear")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('ResNet18 shear influence (Training set)')
plt.legend()

# %%
plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['val_accuracy'], label = "ResNet18")
plt.plot(historyResNet18_shear['Unnamed: 0'], historyResNet18_shear['val_accuracy'], label = "ResNet18 + shear")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('ResNet18 shear influence (Test set)')
plt.legend()

# %%
historyResNet18 = pd.read_csv('ResNet18_v2.csv')
historyResNet18_shift = pd.read_csv('ResNet18_augmentation_shifts.csv')

plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['accuracy'], label = "ResNet18")
plt.plot(historyResNet18_shift['Unnamed: 0'], historyResNet18_shift['accuracy'], label = "ResNet18 + shifts")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('ResNet18 shifts influence (Training set)')
plt.legend()

# %%
plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['val_accuracy'], label = "ResNet18")
plt.plot(historyResNet18_shift['Unnamed: 0'], historyResNet18_shift['val_accuracy'], label = "ResNet18 + shifts")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('ResNet18 shifts influence (Test set)')
plt.legend()

# %%
historyResNet18 = pd.read_csv('ResNet18_v2.csv')
historyResNet18_rotation = pd.read_csv('ResNet18_augmentation_rotation.csv')

plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['accuracy'], label = "ResNet18")
plt.plot(historyResNet18_rotation['Unnamed: 0'].head(80), historyResNet18_rotation['accuracy'].head(80), label = "ResNet18 + rotation")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('ResNet18 rotation influence (Training set)')
plt.legend()

# %%
plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['val_accuracy'], label = "ResNet18")
plt.plot(historyResNet18_rotation['Unnamed: 0'].head(80), historyResNet18_rotation['val_accuracy'].head(80), label = "ResNet18 + rotation")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('ResNet18 rotation influence (Test set)')
plt.legend()

# %%
historyResNet18 = pd.read_csv('ResNet18_v2.csv')
historyResNet18_cshift = pd.read_csv('ResNet18_augmentation_channel_shift.csv')

plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['accuracy'], label = "ResNet18")
plt.plot(historyResNet18_cshift['Unnamed: 0'].head(80), historyResNet18_cshift['accuracy'].head(80), label = "ResNet18 + channel shift")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('ResNet18 channel shift influence (Training set)')
plt.legend()

# %%
plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['val_accuracy'], label = "ResNet18")
plt.plot(historyResNet18_cshift['Unnamed: 0'], historyResNet18_cshift['val_accuracy'], label = "ResNet18 + channel shift")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('ResNet18 channel shift influence (Test set)')
plt.legend()

# %%
historyResNet18 = pd.read_csv('ResNet18_v2.csv')
historyResNet18_cutmix = pd.read_csv('ResNet18_augmentation_cutmix.csv')

plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['accuracy'], label = "ResNet18")
plt.plot(historyResNet18_cutmix['Unnamed: 0'].head(80), historyResNet18_cutmix['accuracy'].head(80), label = "ResNet18 + cutmix")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('ResNet18 cutmix influence (Training set)')
plt.legend()

# %%
plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['val_accuracy'], label = "ResNet18")
plt.plot(historyResNet18_cutmix['Unnamed: 0'].head(80), historyResNet18_cutmix['val_accuracy'].head(80), label = "ResNet18 + cutmix")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('ResNet18 cutmix influence (Test set)')
plt.legend()

# %%
plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['accuracy'], label = "ResNet18")
plt.plot(historyResNet18_cshift['Unnamed: 0'].head(80), historyResNet18_cshift['accuracy'].head(80), label = "ResNet18 + channel shift")
plt.plot(historyResNet18_zoom['Unnamed: 0'], historyResNet18_zoom['accuracy'], label = "ResNet18 + zoom")
plt.plot(historyResNet18_shear['Unnamed: 0'], historyResNet18_shear['accuracy'], label = "ResNet18 + shear")
plt.plot(historyResNet18_rotation['Unnamed: 0'].head(80), historyResNet18_rotation['accuracy'].head(80), label = "ResNet18 + rotation")
plt.plot(historyResNet18_shift['Unnamed: 0'], historyResNet18_shift['accuracy'], label = "ResNet18 + shifts")
plt.plot(historyResNet18_cutmix['Unnamed: 0'].head(80), historyResNet18_cutmix['accuracy'].head(80), label = "ResNet18 + cutmix")

plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('ResNet18 augmentation influence (Training set)')
plt.legend()

# %%
plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['val_accuracy'], label = "ResNet18")
plt.plot(historyResNet18_cshift['Unnamed: 0'].head(80), historyResNet18_cshift['val_accuracy'].head(80), label = "ResNet18 + channel shift")
plt.plot(historyResNet18_zoom['Unnamed: 0'], historyResNet18_zoom['val_accuracy'], label = "ResNet18 + zoom")
plt.plot(historyResNet18_shear['Unnamed: 0'], historyResNet18_shear['val_accuracy'], label = "ResNet18 + shear")
plt.plot(historyResNet18_rotation['Unnamed: 0'].head(80), historyResNet18_rotation['val_accuracy'].head(80), label = "ResNet18 + rotation")
plt.plot(historyResNet18_shift['Unnamed: 0'], historyResNet18_shift['val_accuracy'], label = "ResNet18 + shifts")
plt.plot(historyResNet18_cutmix['Unnamed: 0'].head(80), historyResNet18_cutmix['val_accuracy'].head(80), label = "ResNet18 + cutmix")

plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('ResNet18 channel shift influence (Test set)')
plt.legend()

# %%
historyResNet18 = pd.read_csv('ResNet18_v2.csv')
historyResNet18_all = pd.read_csv('ResNet18_augmentation_all.csv')
historyResNet18_all2 = pd.read_csv('ResNet18_augmentation_all_2.csv')

plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['val_accuracy'], label = "ResNet18")
plt.plot(historyResNet18_all['Unnamed: 0'].head(80), historyResNet18_all['val_accuracy'].head(80), label = "ResNet18 all augmentations")
plt.plot(historyResNet18_all2['Unnamed: 0'], historyResNet18_all2['val_accuracy'], label = "ResNet18 all augmentations 2")

plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('ResNet18 channel shift influence (Test set)')
plt.legend()

# %%
plt.plot(historyResNet18['Unnamed: 0'], historyResNet18['accuracy'], label = "ResNet18")
plt.plot(historyResNet18_all['Unnamed: 0'], historyResNet18_all['accuracy'], label = "ResNet18 all augmentations")
plt.plot(historyResNet18_all2['Unnamed: 0'], historyResNet18_all2['accuracy'], label = "ResNet18 all augmentations 2")

plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('ResNet18 channel shift influence (Test set)')
plt.legend()

# %%
import random
import numpy as np


class CutMixImageDataGenerator():
    def __init__(self, generator1, generator2, img_size, batch_size):
        self.batch_index = 0
        self.samples = generator1.samples
        self.class_indices = generator1.class_indices
        self.generator1 = generator1
        self.generator2 = generator2
        self.img_size = img_size
        self.batch_size = batch_size

    def reset_index(self):  # Ordering Reset (If Shuffle is True, Shuffle Again)
        self.generator1._set_index_array()
        self.generator2._set_index_array()

    def reset(self):
        self.batch_index = 0
        self.generator1.reset()
        self.generator2.reset()
        self.reset_index()

    def get_steps_per_epoch(self):
        quotient, remainder = divmod(self.samples, self.batch_size)
        return (quotient + 1) if remainder else quotient
    
    def __len__(self):
        self.get_steps_per_epoch()

    def __next__(self):
        if self.batch_index == 0: self.reset()

        crt_idx = self.batch_index * self.batch_size
        if self.samples > crt_idx + self.batch_size:
            self.batch_index += 1
        else:  # If current index over number of samples
            self.batch_index = 0

        reshape_size = self.batch_size
        last_step_start_idx = (self.get_steps_per_epoch()-1) * self.batch_size
        if crt_idx == last_step_start_idx:
            reshape_size = self.samples - last_step_start_idx
            
        X_1, y_1 = self.generator1.next()
        X_2, y_2 = self.generator2.next()
        
        cut_ratio = np.random.beta(a=1, b=1, size=reshape_size)
        cut_ratio = np.clip(cut_ratio, 0.2, 0.8)
        label_ratio = cut_ratio.reshape(reshape_size, 1)
        cut_img = X_2

        X = X_1
        for i in range(reshape_size):
            cut_size = int((self.img_size-1) * cut_ratio[i])
            y1 = random.randint(0, (self.img_size-1) - cut_size)
            x1 = random.randint(0, (self.img_size-1) - cut_size)
            y2 = y1 + cut_size
            x2 = x1 + cut_size
            cut_arr = cut_img[i][y1:y2, x1:x2]
            cutmix_img = X_1[i]
            cutmix_img[y1:y2, x1:x2] = cut_arr
            X[i] = cutmix_img
            
        y = y_1 * (1 - (label_ratio ** 2)) + y_2 * (label_ratio ** 2)
        return X, y

    def __iter__(self):
        while True:
            yield next(self)

# %%
datagen=ImageDataGenerator(

    fill_mode='nearest'
)

imagegen=datagen.flow_from_directory('data/train',batch_size=10, shuffle=True)
imagegen2=datagen.flow_from_directory('data/train',batch_size=10, shuffle=True)

cutmix = CutMixImageDataGenerator(imagegen, imagegen2, 255, 10) 

for i in range(4):
    plt.imshow(cutmix.__next__()[0][0].astype('uint8'))
    plt.show()
# Out:
# Found 90000 images belonging to 10 classes.
# Found 90000 images belonging to 10 classes.

# %%
historyCNN = pd.read_csv('CNN_na_czysto.csv')
historyCNN_cutmix = pd.read_csv('CNN_augmentation_cutmix.csv')

plt.plot(historyCNN['Unnamed: 0'].head(80), historyCNN['accuracy'].head(80), label = "CNN")
plt.plot(historyCNN_cutmix['Unnamed: 0'], historyCNN_cutmix['accuracy'].head(80), label = "CNN + cutmix")
plt.xlabel('Iterations')
plt.ylabel('Training Set Accuracy')

plt.title('CNN cutmix influence (Training set)')
plt.legend()

# %%
plt.plot(historyCNN['Unnamed: 0'].head(80), historyCNN['val_accuracy'].head(80), label = "CNN")
plt.plot(historyCNN_cutmix['Unnamed: 0'], historyCNN_cutmix['val_accuracy'].head(80), label = "CNN + cutmix")
plt.xlabel('Iterations')
plt.ylabel('Test Set Accuracy')

plt.title('CNN cutmix influence (Test set)')
plt.legend()
